# %% [markdown]
# # Evaluation

# %%
import pandas as pd
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
hotel_rev = pd.read_csv('HotelRevHelpfulness.csv')
hotel_rev.head()
# Out:
#    hotelId  aveHelpfulnessRatioUser  stdevHelpfulnessRatioUser  \
# 0    17420                 1.000000                   0.000000
# 1     1397                 0.772487                   0.377321
# 2     1348                 0.715473                   0.300437
# 3     5940                 0.521250                   0.481675
# 4       38                 0.603175                   0.246926
#
#    pcReviewsExceedMinHelpfulnessSupport  numReviewsUser  numReviewsHotel  \
# 0                              0.666667               3               16
# 1                              0.500000              12              233
# 2                              0.833333              12              302
# 3                              0.222222              36                6
# 4                              1.000000               2              271
#
#    ratingUser  numberSubRatingsUser  subRatingMeanUser  subRatingStdevUser  \
# 0           5                     4           4.000000            0.000000
# 1           5                     0           0.000000            0.000000
# 2           4                     7           3.714286            0.755929
# 3           1                     4           1.000000            0.000000
# 4           3                     0           0.000000            0.000000
#
#    ...  completeness_2  completeness_3  numberTermsEntry  \
# 0  ...               0               1               182
# 1  ...               0               0               158
# 2  ...               0               3                59
# 3  ...               0               0                95
# 4  ...               0               0                43
#
#    percentageAlphaCharsEntry  fractionUpperCaseCharsEntry  \
# 0                   0.788474                     0.025703
# 1                   0.791888                     0.012594
# 2                   0.799639                     0.024831
# 3                   0.782212                     0.029155
# 4                   0.805128                     0.028662
#
#    fractionYouVsIEntry  numberTermsSummaryQuote  \
# 0             0.500000                        6
# 1             0.500000                        1
# 2             0.333333                        4
# 3             0.500000                        2
# 4             0.000000                        1
#
#    percentageAlphaCharsSummaryQuote  fractionUpperCaseCharsSummaryQuote  \
# 0                          0.815789                            0.096774
# 1                          1.000000                            0.083333
# 2                          0.828571                            0.034483
# 3                          0.800000                            0.062500
# 4                          1.000000                            0.142857
#
#    reviewHelpfulness
# 0                  1
# 1                  1
# 2                  0
# 3                  0
# 4                  0
#
# [5 rows x 25 columns]

# %%
def create_correlation_heatmap(df,pdf_fn,target_list=None,savefig=False):
    """A function to create a seaborn heatmap and save to file"""
    correlation_df = df.corr()
    
    if isinstance(target_list,list):
        correlation_df=df[df.index.isin(target_list)]
        
    plt.subplots(figsize=(50, 50))
    
    sns.heatmap(correlation_df
                , xticklabels=correlation_df.columns
                , yticklabels=correlation_df.columns
                , annot=True)
    if savefig:
        with PdfPages(pdf_fn) as pp:
            pp.savefig(plt.gcf())
            
    return correlation_df

# %% [markdown]
# Describe the datasest

# %%
hotel_rev.describe().T
# Out:
#                                       count         mean          std  \
# hotelId                               486.0  7134.302469  7767.184440
# aveHelpfulnessRatioUser               486.0     0.719262     0.153199
# stdevHelpfulnessRatioUser             486.0     0.285824     0.151374
# pcReviewsExceedMinHelpfulnessSupport  486.0     0.549716     0.274827
# numReviewsUser                        486.0    20.034979    25.519445
# numReviewsHotel                       486.0   266.216049   393.222191
# ratingUser                            486.0     3.777778     1.197936
# numberSubRatingsUser                  486.0     3.341564     2.634153
# subRatingMeanUser                     486.0     2.528238     1.993384
# subRatingStdevUser                    486.0     0.382220     0.429951
# aveRatingUser                         486.0     3.787185     0.667251
# stdevRatingUser                       486.0     0.926015     0.492816
# aveRatingHotel                        486.0     3.818721     0.592864
# stdevRatingHotel                      486.0     1.123437     0.238706
# completeness_1                        486.0     2.234568     1.847405
# completeness_2                        486.0     0.448560     0.825139
# completeness_3                        486.0     1.216049     1.424611
# numberTermsEntry                      486.0   134.427984   133.192187
# percentageAlphaCharsEntry             486.0     0.699573     0.242706
# fractionUpperCaseCharsEntry           486.0     0.028539     0.015110
# fractionYouVsIEntry                   486.0     0.313249     0.355809
# numberTermsSummaryQuote               486.0     3.530864     1.716528
# percentageAlphaCharsSummaryQuote      486.0     0.837713     0.067407
# fractionUpperCaseCharsSummaryQuote    486.0     0.109177     0.083999
#
#                                            min         25%          50%  \
# hotelId                               2.000000  480.000000  3953.000000
# aveHelpfulnessRatioUser               0.000000    0.635179     0.734986
# stdevHelpfulnessRatioUser             0.000000    0.166669     0.319642
# pcReviewsExceedMinHelpfulnessSupport  0.028302    0.333333     0.500000
# numReviewsUser                        1.000000    5.000000    12.000000
# numReviewsHotel                       1.000000   58.750000   146.000000
# ratingUser                            1.000000    3.000000     4.000000
# numberSubRatingsUser                  0.000000    0.000000     4.000000
# subRatingMeanUser                     0.000000    0.000000     3.171429
# subRatingStdevUser                    0.000000    0.000000     0.377964
# aveRatingUser                         1.000000    3.500000     3.843137
# stdevRatingUser                       0.000000    0.707107     0.957427
# aveRatingHotel                        1.000000    3.458896     3.905709
# stdevRatingHotel                      0.000000    0.992650     1.153626
# completeness_1                        0.000000    0.000000     2.000000
# completeness_2                        0.000000    0.000000     0.000000
# completeness_3                        0.000000    0.000000     1.000000
# numberTermsEntry                      0.000000   52.000000   100.000000
# percentageAlphaCharsEntry             0.000000    0.770554     0.781748
# fractionUpperCaseCharsEntry           0.000000    0.021752     0.028661
# fractionYouVsIEntry                   0.000000    0.000000     0.200000
# numberTermsSummaryQuote               0.000000    2.000000     3.000000
# percentageAlphaCharsSummaryQuote      0.423077    0.800000     0.841507
# fractionUpperCaseCharsSummaryQuote    0.000000    0.050000     0.090909
#
#                                                75%           max
# hotelId                               12087.500000  28633.000000
# aveHelpfulnessRatioUser                   0.833333      1.000000
# stdevHelpfulnessRatioUser                 0.412321      0.656599
# pcReviewsExceedMinHelpfulnessSupport      0.750000      1.000000
# numReviewsUser                           24.000000    165.000000
# numReviewsHotel                         284.500000   2843.000000
# ratingUser                                5.000000      5.000000
# numberSubRatingsUser                      6.000000      7.000000
# subRatingMeanUser                         4.333333      5.000000
# subRatingStdevUser                        0.577350      1.914854
# aveRatingUser                             4.151907      5.000000
# stdevRatingUser                           1.205827      2.828427
# aveRatingHotel                            4.227493      5.000000
# stdevRatingHotel                          1.269349      2.138090
# completeness_1                            5.000000      5.000000
# completeness_2                            0.000000      2.000000
# completeness_3                            2.000000      4.000000
# numberTermsEntry                        180.750000   1075.000000
# percentageAlphaCharsEntry                 0.790812      0.821138
# fractionUpperCaseCharsEntry               0.036196      0.093230
# fractionYouVsIEntry                       0.500000      1.000000
# numberTermsSummaryQuote                   4.000000     10.000000
# percentageAlphaCharsSummaryQuote          0.880000      1.000000
# fractionUpperCaseCharsSummaryQuote        0.153846      1.000000

# %%
create_correlation_heatmap(df=hotel_rev,pdf_fn='NA.pdf',target_list=None,savefig=False)
# Out:
#                                        hotelId  aveHelpfulnessRatioUser  \
# hotelId                               1.000000                 0.101142
# aveHelpfulnessRatioUser               0.101142                 1.000000
# stdevHelpfulnessRatioUser             0.172848                -0.452146
# pcReviewsExceedMinHelpfulnessSupport -0.214297                 0.254958
# numReviewsUser                        0.232747                 0.007692
# numReviewsHotel                      -0.343033                -0.058714
# ratingUser                           -0.063223                 0.068572
# numberSubRatingsUser                  0.112453                -0.078457
# subRatingMeanUser                     0.107137                 0.001806
# subRatingStdevUser                    0.060528                -0.059356
# aveRatingUser                        -0.010839                 0.169081
# stdevRatingUser                       0.181427                -0.054872
# aveRatingHotel                       -0.068200                -0.016088
# stdevRatingHotel                     -0.058399                -0.005285
# completeness_1                        0.103826                -0.117620
# completeness_2                        0.061490                -0.120946
# completeness_3                        0.071479                -0.116576
# numberTermsEntry                      0.033461                 0.121665
# percentageAlphaCharsEntry            -0.000345                -0.039500
# fractionUpperCaseCharsEntry          -0.041387                -0.037087
# fractionYouVsIEntry                   0.060641                 0.090907
# numberTermsSummaryQuote               0.117865                 0.002261
# percentageAlphaCharsSummaryQuote     -0.016849                -0.018155
# fractionUpperCaseCharsSummaryQuote   -0.091800                 0.001578
#
#                                       stdevHelpfulnessRatioUser  \
# hotelId                                                0.172848
# aveHelpfulnessRatioUser                               -0.452146
# stdevHelpfulnessRatioUser                              1.000000
# pcReviewsExceedMinHelpfulnessSupport                  -0.721975
# numReviewsUser                                         0.233052
# numReviewsHotel                                        0.038276
# ratingUser                                             0.030888
# numberSubRatingsUser                                   0.186257
# subRatingMeanUser                                      0.156531
# subRatingStdevUser                                     0.093418
# aveRatingUser                                          0.055964
# stdevRatingUser                                        0.322827
# aveRatingHotel                                         0.060199
# stdevRatingHotel                                      -0.070626
# completeness_1                                         0.246022
# completeness_2                                         0.202244
# completeness_3                                         0.223405
# numberTermsEntry                                       0.043976
# percentageAlphaCharsEntry                              0.030892
# fractionUpperCaseCharsEntry                            0.001069
# fractionYouVsIEntry                                    0.009780
# numberTermsSummaryQuote                                0.032054
# percentageAlphaCharsSummaryQuote                      -0.050760
# fractionUpperCaseCharsSummaryQuote                    -0.020476
#
#                                       pcReviewsExceedMinHelpfulnessSupport  \
# hotelId                                                          -0.214297
# aveHelpfulnessRatioUser                                           0.254958
# stdevHelpfulnessRatioUser                                        -0.721975
# pcReviewsExceedMinHelpfulnessSupport                              1.000000
# numReviewsUser                                                   -0.275932
# numReviewsHotel                                                   0.002154
# ratingUser                                                       -0.056548
# numberSubRatingsUser                                             -0.216403
# subRatingMeanUser                                                -0.181310
# subRatingStdevUser                                               -0.132638
# aveRatingUser                                                    -0.050807
# stdevRatingUser                                                  -0.305595
# aveRatingHotel                                                   -0.111750
# stdevRatingHotel                                                  0.096644
# completeness_1                                                   -0.275948
# completeness_2                                                   -0.220604
# completeness_3                                                   -0.258149
# numberTermsEntry                                                 -0.050343
# percentageAlphaCharsEntry                                        -0.085270
# fractionUpperCaseCharsEntry                                      -0.052217
# fractionYouVsIEntry                                              -0.050918
# numberTermsSummaryQuote                                          -0.048312
# percentageAlphaCharsSummaryQuote                                  0.034361
# fractionUpperCaseCharsSummaryQuote                                0.070593
#
#                                       numReviewsUser  numReviewsHotel  \
# hotelId                                     0.232747        -0.343033
# aveHelpfulnessRatioUser                     0.007692        -0.058714
# stdevHelpfulnessRatioUser                   0.233052         0.038276
# pcReviewsExceedMinHelpfulnessSupport       -0.275932         0.002154
# numReviewsUser                              1.000000        -0.092861
# numReviewsHotel                            -0.092861         1.000000
# ratingUser                                  0.060416         0.097860
# numberSubRatingsUser                        0.136835         0.014386
# subRatingMeanUser                           0.129732        -0.015297
# subRatingStdevUser                          0.091878         0.042893
# aveRatingUser                               0.061050         0.039969
# stdevRatingUser                             0.138248        -0.001815
# aveRatingHotel                             -0.021396         0.098332
# stdevRatingHotel                           -0.042230         0.027892
# completeness_1                              0.143406         0.083450
# completeness_2                              0.133792         0.099742
# completeness_3                              0.117587         0.099541
# numberTermsEntry                            0.005789         0.262337
# percentageAlphaCharsEntry                  -0.025479         0.112483
# fractionUpperCaseCharsEntry                -0.034657         0.115305
# fractionYouVsIEntry                        -0.001829         0.048068
# numberTermsSummaryQuote                     0.111788        -0.022100
# percentageAlphaCharsSummaryQuote           -0.078552        -0.051362
# fractionUpperCaseCharsSummaryQuote         -0.060009         0.030060
#
#                                       ratingUser  numberSubRatingsUser  \
# hotelId                                -0.063223              0.112453
# aveHelpfulnessRatioUser                 0.068572             -0.078457
# stdevHelpfulnessRatioUser               0.030888              0.186257
# pcReviewsExceedMinHelpfulnessSupport   -0.056548             -0.216403
# numReviewsUser                          0.060416              0.136835
# numReviewsHotel                         0.097860              0.014386
# ratingUser                              1.000000             -0.017061
# numberSubRatingsUser                   -0.017061              1.000000
# subRatingMeanUser                       0.273183              0.840759
# subRatingStdevUser                     -0.283181              0.629435
# aveRatingUser                           0.510964             -0.049845
# stdevRatingUser                        -0.139683              0.143739
# aveRatingHotel                          0.449340              0.156422
# stdevRatingHotel                       -0.270000             -0.110665
# completeness_1                         -0.001553              0.895721
# completeness_2                          0.034302              0.656954
# completeness_3                          0.082558              0.822038
# numberTermsEntry                       -0.022831              0.291816
# percentageAlphaCharsEntry               0.005792              0.274607
# fractionUpperCaseCharsEntry             0.036439              0.165850
# fractionYouVsIEntry                     0.118050              0.060795
# numberTermsSummaryQuote                -0.050804              0.115768
# percentageAlphaCharsSummaryQuote        0.023186             -0.008058
# fractionUpperCaseCharsSummaryQuote      0.010986             -0.046848
#
#                                       subRatingMeanUser  subRatingStdevUser  \
# hotelId                                        0.107137            0.060528
# aveHelpfulnessRatioUser                        0.001806           -0.059356
# stdevHelpfulnessRatioUser                      0.156531            0.093418
# pcReviewsExceedMinHelpfulnessSupport          -0.181310           -0.132638
# numReviewsUser                                 0.129732            0.091878
# numReviewsHotel                               -0.015297            0.042893
# ratingUser                                     0.273183           -0.283181
# numberSubRatingsUser                           0.840759            0.629435
# subRatingMeanUser                              1.000000            0.449177
# subRatingStdevUser                             0.449177            1.000000
# aveRatingUser                                  0.120877           -0.144686
# stdevRatingUser                                0.078354            0.123375
# aveRatingHotel                                 0.224773           -0.035425
# stdevRatingHotel                              -0.141036            0.084039
# completeness_1                                 0.687189            0.525164
# completeness_2                                 0.400187            0.348111
# completeness_3                                 0.623505            0.446803
# numberTermsEntry                               0.199767            0.254155
# percentageAlphaCharsEntry                      0.232300            0.207700
# fractionUpperCaseCharsEntry                    0.141218            0.110613
# fractionYouVsIEntry                            0.063166            0.066996
# numberTermsSummaryQuote                        0.105293            0.142437
# percentageAlphaCharsSummaryQuote               0.005513           -0.044327
# fractionUpperCaseCharsSummaryQuote            -0.044947           -0.048075
#
#                                       ...  completeness_1  completeness_2  \
# hotelId                               ...        0.103826        0.061490
# aveHelpfulnessRatioUser               ...       -0.117620       -0.120946
# stdevHelpfulnessRatioUser             ...        0.246022        0.202244
# pcReviewsExceedMinHelpfulnessSupport  ...       -0.275948       -0.220604
# numReviewsUser                        ...        0.143406        0.133792
# numReviewsHotel                       ...        0.083450        0.099742
# ratingUser                            ...       -0.001553        0.034302
# numberSubRatingsUser                  ...        0.895721        0.656954
# subRatingMeanUser                     ...        0.687189        0.400187
# subRatingStdevUser                    ...        0.525164        0.348111
# aveRatingUser                         ...       -0.047061       -0.045636
# stdevRatingUser                       ...        0.168183        0.160878
# aveRatingHotel                        ...        0.184786        0.196706
# stdevRatingHotel                      ...       -0.126144       -0.162354
# completeness_1                        ...        1.000000        0.789734
# completeness_2                        ...        0.789734        1.000000
# completeness_3                        ...        0.904368        0.859298
# numberTermsEntry                      ...        0.269997        0.207677
# percentageAlphaCharsEntry             ...        0.286444        0.183613
# fractionUpperCaseCharsEntry           ...        0.145408        0.117755
# fractionYouVsIEntry                   ...        0.050910        0.057960
# numberTermsSummaryQuote               ...        0.069234        0.074638
# percentageAlphaCharsSummaryQuote      ...        0.023220       -0.007668
# fractionUpperCaseCharsSummaryQuote    ...       -0.022348       -0.038204
#
#                                       completeness_3  numberTermsEntry  \
# hotelId                                     0.071479          0.033461
# aveHelpfulnessRatioUser                    -0.116576          0.121665
# stdevHelpfulnessRatioUser                   0.223405          0.043976
# pcReviewsExceedMinHelpfulnessSupport       -0.258149         -0.050343
# numReviewsUser                              0.117587          0.005789
# numReviewsHotel                             0.099541          0.262337
# ratingUser                                  0.082558         -0.022831
# numberSubRatingsUser                        0.822038          0.291816
# subRatingMeanUser                           0.623505          0.199767
# subRatingStdevUser                          0.446803          0.254155
# aveRatingUser                              -0.036560          0.010941
# stdevRatingUser                             0.151640          0.078873
# aveRatingHotel                              0.184294          0.086952
# stdevRatingHotel                           -0.138841         -0.016414
# completeness_1                              0.904368          0.269997
# completeness_2                              0.859298          0.207677
# completeness_3                              1.000000          0.257924
# numberTermsEntry                            0.257924          1.000000
# percentageAlphaCharsEntry                   0.235497          0.345251
# fractionUpperCaseCharsEntry                 0.156951          0.202946
# fractionYouVsIEntry                         0.062651          0.221311
# numberTermsSummaryQuote                     0.068515          0.201773
# percentageAlphaCharsSummaryQuote            0.033143         -0.123411
# fractionUpperCaseCharsSummaryQuote         -0.048726         -0.026567
#
#                                       percentageAlphaCharsEntry  \
# hotelId                                               -0.000345
# aveHelpfulnessRatioUser                               -0.039500
# stdevHelpfulnessRatioUser                              0.030892
# pcReviewsExceedMinHelpfulnessSupport                  -0.085270
# numReviewsUser                                        -0.025479
# numReviewsHotel                                        0.112483
# ratingUser                                             0.005792
# numberSubRatingsUser                                   0.274607
# subRatingMeanUser                                      0.232300
# subRatingStdevUser                                     0.207700
# aveRatingUser                                         -0.006289
# stdevRatingUser                                        0.043155
# aveRatingHotel                                         0.041062
# stdevRatingHotel                                      -0.005527
# completeness_1                                         0.286444
# completeness_2                                         0.183613
# completeness_3                                         0.235497
# numberTermsEntry                                       0.345251
# percentageAlphaCharsEntry                              1.000000
# fractionUpperCaseCharsEntry                            0.646592
# fractionYouVsIEntry                                    0.304106
# numberTermsSummaryQuote                                0.044399
# percentageAlphaCharsSummaryQuote                       0.013716
# fractionUpperCaseCharsSummaryQuote                    -0.044515
#
#                                       fractionUpperCaseCharsEntry  \
# hotelId                                                 -0.041387
# aveHelpfulnessRatioUser                                 -0.037087
# stdevHelpfulnessRatioUser                                0.001069
# pcReviewsExceedMinHelpfulnessSupport                    -0.052217
# numReviewsUser                                          -0.034657
# numReviewsHotel                                          0.115305
# ratingUser                                               0.036439
# numberSubRatingsUser                                     0.165850
# subRatingMeanUser                                        0.141218
# subRatingStdevUser                                       0.110613
# aveRatingUser                                            0.054944
# stdevRatingUser                                          0.065823
# aveRatingHotel                                           0.050826
# stdevRatingHotel                                        -0.042715
# completeness_1                                           0.145408
# completeness_2                                           0.117755
# completeness_3                                           0.156951
# numberTermsEntry                                         0.202946
# percentageAlphaCharsEntry                                0.646592
# fractionUpperCaseCharsEntry                              1.000000
# fractionYouVsIEntry                                      0.133936
# numberTermsSummaryQuote                                  0.025354
# percentageAlphaCharsSummaryQuote                        -0.010500
# fractionUpperCaseCharsSummaryQuote                      -0.015489
#
#                                       fractionYouVsIEntry  \
# hotelId                                          0.060641
# aveHelpfulnessRatioUser                          0.090907
# stdevHelpfulnessRatioUser                        0.009780
# pcReviewsExceedMinHelpfulnessSupport            -0.050918
# numReviewsUser                                  -0.001829
# numReviewsHotel                                  0.048068
# ratingUser                                       0.118050
# numberSubRatingsUser                             0.060795
# subRatingMeanUser                                0.063166
# subRatingStdevUser                               0.066996
# aveRatingUser                                    0.091576
# stdevRatingUser                                  0.019346
# aveRatingHotel                                   0.065801
# stdevRatingHotel                                 0.007433
# completeness_1                                   0.050910
# completeness_2                                   0.057960
# completeness_3                                   0.062651
# numberTermsEntry                                 0.221311
# percentageAlphaCharsEntry                        0.304106
# fractionUpperCaseCharsEntry                      0.133936
# fractionYouVsIEntry                              1.000000
# numberTermsSummaryQuote                          0.006454
# percentageAlphaCharsSummaryQuote                 0.040048
# fractionUpperCaseCharsSummaryQuote              -0.082741
#
#                                       numberTermsSummaryQuote  \
# hotelId                                              0.117865
# aveHelpfulnessRatioUser                              0.002261
# stdevHelpfulnessRatioUser                            0.032054
# pcReviewsExceedMinHelpfulnessSupport                -0.048312
# numReviewsUser                                       0.111788
# numReviewsHotel                                     -0.022100
# ratingUser                                          -0.050804
# numberSubRatingsUser                                 0.115768
# subRatingMeanUser                                    0.105293
# subRatingStdevUser                                   0.142437
# aveRatingUser                                       -0.110316
# stdevRatingUser                                      0.014308
# aveRatingHotel                                       0.007953
# stdevRatingHotel                                    -0.015500
# completeness_1                                       0.069234
# completeness_2                                       0.074638
# completeness_3                                       0.068515
# numberTermsEntry                                     0.201773
# percentageAlphaCharsEntry                            0.044399
# fractionUpperCaseCharsEntry                          0.025354
# fractionYouVsIEntry                                  0.006454
# numberTermsSummaryQuote                              1.000000
# percentageAlphaCharsSummaryQuote                    -0.233966
# fractionUpperCaseCharsSummaryQuote                  -0.147022
#
#                                       percentageAlphaCharsSummaryQuote  \
# hotelId                                                      -0.016849
# aveHelpfulnessRatioUser                                      -0.018155
# stdevHelpfulnessRatioUser                                    -0.050760
# pcReviewsExceedMinHelpfulnessSupport                          0.034361
# numReviewsUser                                               -0.078552
# numReviewsHotel                                              -0.051362
# ratingUser                                                    0.023186
# numberSubRatingsUser                                         -0.008058
# subRatingMeanUser                                             0.005513
# subRatingStdevUser                                           -0.044327
# aveRatingUser                                                 0.001925
# stdevRatingUser                                              -0.056215
# aveRatingHotel                                                0.057185
# stdevRatingHotel                                             -0.003839
# completeness_1                                                0.023220
# completeness_2                                               -0.007668
# completeness_3                                                0.033143
# numberTermsEntry                                             -0.123411
# percentageAlphaCharsEntry                                     0.013716
# fractionUpperCaseCharsEntry                                  -0.010500
# fractionYouVsIEntry                                           0.040048
# numberTermsSummaryQuote                                      -0.233966
# percentageAlphaCharsSummaryQuote                              1.000000
# fractionUpperCaseCharsSummaryQuote                           -0.042494
#
#                                       fractionUpperCaseCharsSummaryQuote
# hotelId                                                        -0.091800
# aveHelpfulnessRatioUser                                         0.001578
# stdevHelpfulnessRatioUser                                      -0.020476
# pcReviewsExceedMinHelpfulnessSupport                            0.070593
# numReviewsUser                                                 -0.060009
# numReviewsHotel                                                 0.030060
# ratingUser                                                      0.010986
# numberSubRatingsUser                                           -0.046848
# subRatingMeanUser                                              -0.044947
# subRatingStdevUser                                             -0.048075
# aveRatingUser                                                   0.024904
# stdevRatingUser                                                -0.044133
# aveRatingHotel                                                  0.002840
# stdevRatingHotel                                                0.068509
# completeness_1                                                 -0.022348
# completeness_2                                                 -0.038204
# completeness_3                                                 -0.048726
# numberTermsEntry                                               -0.026567
# percentageAlphaCharsEntry                                      -0.044515
# fractionUpperCaseCharsEntry                                    -0.015489
# fractionYouVsIEntry                                            -0.082741
# numberTermsSummaryQuote                                        -0.147022
# percentageAlphaCharsSummaryQuote                               -0.042494
# fractionUpperCaseCharsSummaryQuote                              1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# 'reviewHelpfulness' is the class label. `1` is positive and `0` is negative.

# %%
n = hotel_rev.shape[0]
np = hotel_rev['reviewHelpfulness'].sum()
nn = n - np
print('{} Samples'.format(n))
print('{} Positive \n{} Negative'.format(np,nn))
# Out:
# 486 Samples
# 308 Positive
# 178 Negative

# %%
y = hotel_rev.pop('reviewHelpfulness').values
Xraw = hotel_rev.values
scaler = StandardScaler()
X = scaler.fit_transform(Xraw)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=1/3)
print("X_test shape: ",X_test.shape)
# Out:
# X_test shape:  (162, 24)

# %%
mnb = GaussianNB()
hotel_rev_NB = mnb.fit(X_train, y_train)
y_dash = hotel_rev_NB.predict(X_test)

# %% [markdown]
# ### Accuracy & Confusion Matrix
# With the confusion matrix, rows are actual and columns are predicted.
# If 0 is negative and 1 is positive `C(0,0)` is TN and `C(1,1)` is TP.
# TN, FP
# FN, TP

# %%
acc = accuracy_score(y_test, y_dash)
print("Accuracy: {0:.2f}".format(acc)) 
confusion = confusion_matrix(y_test, y_dash)
print("Confusion matrix:\n{}".format(confusion))
# Out:
# Accuracy: 0.69
# Confusion matrix:
# [[42 20]
#  [30 70]]

# %%
disp = ConfusionMatrixDisplay(confusion)
fig, ax = plt.subplots(figsize=(3,3))
disp.plot(ax=ax)

# %%
report = classification_report(y_test, y_dash, target_names = ['Not Helpful','Helpful'])
print("Report:\n{}".format(report))
# Out:
# Report:
#               precision    recall  f1-score   support
#
#  Not Helpful       0.58      0.68      0.63        62
#      Helpful       0.78      0.70      0.74       100
#
#     accuracy                           0.69       162
#    macro avg       0.68      0.69      0.68       162
# weighted avg       0.70      0.69      0.69       162

# %% [markdown]
# ## SVM

# %%
 from sklearn.svm import SVC
svm = SVC(kernel = 'linear',C=1)
hotel_rev_SVM = svm.fit(X_train, y_train)
y_dash = hotel_rev_SVM.predict(X_test)

# %%
acc = accuracy_score(y_test, y_dash)
print("Accuracy: {0:.2f}".format(acc)) 
confusion = confusion_matrix(y_test, y_dash)
print("Confusion matrix:\n{}".format(confusion))
# Out:
# Accuracy: 0.70
# Confusion matrix:
# [[34 28]
#  [21 79]]

# %%
report = classification_report(y_test, y_dash, target_names = ['Not Helpful','Helpful'])
print("Report:\n{}".format(report))
# Out:
# Report:
#               precision    recall  f1-score   support
#
#  Not Helpful       0.62      0.55      0.58        62
#      Helpful       0.74      0.79      0.76       100
#
#     accuracy                           0.70       162
#    macro avg       0.68      0.67      0.67       162
# weighted avg       0.69      0.70      0.69       162

# %% [markdown]
# ### F1 Measure

# %%
from sklearn.metrics import f1_score
kNN = KNeighborsClassifier(n_neighbors=3)  
dtree = DecisionTreeClassifier(criterion='entropy')
mnb = GaussianNB()
models = [mnb,kNN,dtree]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    random_state=0, 
                                                    test_size=1/3)
print('F1 Measure')
for m in models:
    mm = m.fit(X_train, y_train)
    y_pred = mm.predict(X_test)
    f1s = f1_score(y_test, y_pred) 
    print("F1 Score on Test set {:22} {:.2f}".format(type(m).__name__, f1s))
# Out:
# F1 Measure
# F1 Score on Test set GaussianNB             0.74
# F1 Score on Test set KNeighborsClassifier   0.73
# F1 Score on Test set DecisionTreeClassifier 0.73

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (324, 24)
# (162, 24)

# %% [markdown]
# ## Cross Validation
# `cross_val_score` will run a k-fold cross validation.
# Using 4-fold cross validation because my machine has 4 threads (2 cores) and multiple cores are used on the SVM evaluation.
# 5-fold X-Val effectively doubles processing time.

# %%
from sklearn.model_selection import cross_val_score
mnb = GaussianNB()
scores = cross_val_score(mnb, X, y, cv=4)
print("4x CV Accuracy Naive Bayes: {0:.2f}".format(scores.mean())) 
scores
# Out:
# 4x CV Accuracy Naive Bayes: 0.64
# array([0.53278689, 0.66393443, 0.67768595, 0.68595041])

# %%
kNN = KNeighborsClassifier(n_neighbors=3)  
kNN_scores = cross_val_score(kNN, X, y, cv=4)
print("4x CV Accuracy kNNs: {0:.2f}".format(kNN_scores.mean())) 
kNN_scores
# Out:
# 4x CV Accuracy kNNs: 0.64
# array([0.58196721, 0.60655738, 0.69421488, 0.67768595])

# %%
dtree = DecisionTreeClassifier(criterion='entropy')
tree_scores = cross_val_score(dtree, X, y, cv=4)
print("4x CV Accuracy Trees: {0:.2f}".format(tree_scores.mean())) 
tree_scores
# Out:
# 4x CV Accuracy Trees: 0.68
# array([0.69672131, 0.66393443, 0.70247934, 0.66942149])

# %%
# n_jobs = -1 uses all available threads
from sklearn.svm import SVC
svm = SVC(kernel = 'linear',C=1)
svm_scores = cross_val_score(svm, X, y, cv=4, verbose = 0,  n_jobs = -1)
print("4x CV Accuracy SVMs: {0:.2f}".format(svm_scores.mean())) 
svm_scores
# Out:
# 4x CV Accuracy SVMs: 0.72
# array([0.68032787, 0.71311475, 0.76859504, 0.7107438 ])

# %% [markdown]
# SVC wins with 70% accuracy.
# DTrees come in second with 67%.
# k-NN is last at 63%

# %% [markdown]
# ### F1 Score
# A balanced score that measures the harmonic mean between Precision and Recall.

# %%
from sklearn.svm import SVC
svm = SVC(kernel = 'linear',C=1)

# %%
models = [mnb,kNN,dtree,svm]
models = [mnb,kNN,dtree]    # leave out svm, life is too short...
folds = 4

# %%
print('F1 Measure')
for m in models:
    f1_scores = cross_val_score(m, X, y, cv=folds, scoring = 'f1', n_jobs=-1, verbose = 5)
    print("{} x CV {:22} {:.2f}".format(folds, type(m).__name__, f1_scores.mean()))
# Out:
# F1 Measure
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# 4 x CV GaussianNB             0.71
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# 4 x CV KNeighborsClassifier   0.73
# 4 x CV DecisionTreeClassifier 0.76
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.4s finished

# %% [markdown]
# SVM still wins on F1 score.

# %% [markdown]
# ## Precision & Recall

# %%
print('Precision')
for m in models:
    f1_scores = cross_val_score(m, X, y, cv=folds, scoring = 'precision', n_jobs=-1, verbose = 5)
    print("{} x CV {:22} {:.2f}".format(folds, type(m).__name__, f1_scores.mean()))
# Out:
# Precision
# 4 x CV GaussianNB             0.72
# 4 x CV KNeighborsClassifier   0.70
# 4 x CV DecisionTreeClassifier 0.77
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished

# %%
print('Recall')
for m in models:
    f1_scores = cross_val_score(m, X, y, cv=folds, scoring = 'recall', n_jobs=-1, verbose = 5)
    print("{} x CV {:22} {:.2f}".format(folds, type(m).__name__, f1_scores.mean()))
# Out:
# Recall
# 4 x CV GaussianNB             0.71
# 4 x CV KNeighborsClassifier   0.76
# 4 x CV DecisionTreeClassifier 0.72
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished

# %% [markdown]
# ### ROC AUC analysis

# %%
folds = 4
print('ROC Analysis')
for m in models:
    roc_scores = cross_val_score(m, X, y, cv=folds, scoring = 'roc_auc', n_jobs=-1)
    print("{} x CV {:22} {:.2f}".format(folds, type(m).__name__, roc_scores.mean()))
# Out:
# ROC Analysis
# 4 x CV GaussianNB             0.69
# 4 x CV KNeighborsClassifier   0.63
# 4 x CV DecisionTreeClassifier 0.66

# %% [markdown]
# ### Calculating TP & FP with cross validation
# The hold out validation shows that SVM has a very high FP rate. It has a strong bias towards the majority class (Helpful).
# Here we get a cross-validation estimate of this FP rate.
# To do this we have to make a scorer function to get the FP scores.

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
def tp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 1]
def tn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 0]
def fp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 1]
def fn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 0]
scoring = {'tp' : make_scorer(tp), 'tn' : make_scorer(tn),
           'fp' : make_scorer(fp), 'fn' : make_scorer(fn)}

models = [mnb,kNN,dtree,svm]
models = [mnb,kNN,dtree]

folds = 4
v = 0 #  use 1 or 0

# %%
for m in models:
    cv_results = cross_validate(m, X, y, cv= folds,scoring=scoring, return_train_score=False, 
                                    verbose = v, n_jobs = -1)
    fp_rate = cv_results['test_fp'].sum()/(cv_results['test_fp'].sum()+cv_results['test_tn'].sum())
    tp_rate = cv_results['test_tp'].sum()/(cv_results['test_tp'].sum()+cv_results['test_fn'].sum())
  
    print("{} x CV {:22} FP: {:.2f}  TP: {:.2f}".format(folds, type(m).__name__, fp_rate, tp_rate))
# Out:
# 4 x CV GaussianNB             FP: 0.48  TP: 0.71
# 4 x CV KNeighborsClassifier   FP: 0.57  TP: 0.76
# 4 x CV DecisionTreeClassifier FP: 0.38  TP: 0.73

# %% [markdown]
# The one score SVM does not win on is the FP rate. This is because it has a strong positive bias.
